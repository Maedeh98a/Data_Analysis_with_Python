# %%
import pandas as pd
import numpy as np
csv_df = pd.read_csv("D:\Downlods\Business-employment-data-september-2022-quarter-csv\Business-employment-data-september-2022-quarter-csv.csv")
csv_df.head()
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS   UNITS  Magnitude  \
# 0      BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number          0
# 1      BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number          0
# 2      BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number          0
# 3      BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number          0
# 4      BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number          0
#
#                           Subject                            Group  \
# 0  Business Data Collection - BDC  Industry by employment variable
# 1  Business Data Collection - BDC  Industry by employment variable
# 2  Business Data Collection - BDC  Industry by employment variable
# 3  Business Data Collection - BDC  Industry by employment variable
# 4  Business Data Collection - BDC  Industry by employment variable
#
#   Series_title_1                     Series_title_2 Series_title_3  \
# ...

# %%
import pandas as pd
my_header = ['name', 'department', 'salary_in_dollar', 'city']
no_header_csv_df = pd.read_csv("D:\Downlods\Business-employment-data-september-2022-quarter-csv\Business-employment-data-september-2022-quarter-csv.csv", names=my_header)
no_header_csv_df.head()
# Out:
#                                                                                                                                                                                    name  \
# Series_reference Period  Data_value Suppressed STATUS UNITS  Magnitude Subject                        Group                           Series_title_1                     Series_title_2
# BDCQ.SEA1AA      2011.06 80078      NaN        F      Number 0         Business Data Collection - BDC Industry by employment variable Filled jobs     Agriculture, Forestry and Fishing
#                  2011.09 78324      NaN        F      Number 0         Business Data Collection - BDC Industry by employment variable Filled jobs     Agriculture, Forestry and Fishing
#                  2011.12 85850      NaN        F      Number 0         Business Data Collection - BDC Industry by employment variable Filled jobs     Agriculture, Forestry and Fishing
# ...

# %%
import pandas as pd
excel_df = pd.read_excel("D:\Downlods\Advanced+Pivot+Tables+Course+Files\Course Files\Section 4\Consolidating.xlsx",sheet_name='Customer Info')
excel_df.head()
# Out:
#    Unnamed: 0 Unnamed: 1              Unnamed: 2 Unnamed: 3
# 0         NaN   Order ID                Customer      State
# 1         NaN      20001  Adriana C. Ocampo Uria         AL
# 2         NaN      20002         Albert Einstein         AK
# 3         NaN      20003    Anna K. Behrensmeyer         AZ
# 4         NaN      20004           Blaise Pascal         AR

# %%
import pandas as pd
excel_df = pd.read_excel("D:\Downlods\Advanced+Pivot+Tables+Course+Files\Course Files\Section 4\Consolidating.xlsx")
excel_df.head()
# Out:
#    Unnamed: 0 Unnamed: 1              Unnamed: 2 Unnamed: 3
# 0         NaN   Order ID                Customer      State
# 1         NaN      20001  Adriana C. Ocampo Uria         AL
# 2         NaN      20002         Albert Einstein         AK
# 3         NaN      20003    Anna K. Behrensmeyer         AZ
# 4         NaN      20004           Blaise Pascal         AR

# %%
import pandas as pd
excel_df = pd.read_excel("D:\Downlods\Advanced+Pivot+Tables+Exercise+Files\Maedeh.xlsx")
excel_df.head()
# Out:
#    UniqueID          ParcelID        LandUse  \
# 0       2045  007 00 0 125.00  SINGLE FAMILY
# 1      16918  007 00 0 130.00  SINGLE FAMILY
# 2      54582  007 00 0 138.00  SINGLE FAMILY
# 3      43070  007 00 0 143.00  SINGLE FAMILY
# 4      22714  007 00 0 149.00  SINGLE FAMILY
#
#                       PropertyAddress   SaleDate  SalePrice    LegalReference  \
# 0  1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000  20130412-0036474
# 1  1832  FOX CHASE DR, GOODLETTSVILLE 2014-06-10     366000  20140619-0053768
# 2  1864 FOX CHASE  DR, GOODLETTSVILLE 2016-09-26     435000  20160927-0101718
# 3  1853  FOX CHASE DR, GOODLETTSVILLE 2016-01-29     255000  20160129-0008913
# 4  1829  FOX CHASE DR, GOODLETTSVILLE 2014-10-10     278000  20141015-0095255
#
#   SoldAsVacant                           OwnerName  \
# 0           No           FRAZIER, CYRENTHA LYNETTE
# 1           No             BONER, CHARLES & LESLIE
# 2           No           WILSON, JAMES E. & JOANNE
# ...

# %%
import pandas as pd
excel_df = pd.read_excel("D:\Downlods\Advanced+Pivot+Tables+Course+Files\Course Files\Section 3\Sample Sales Data.xlsx")
excel_df.head()
# Out:
#   Country     Product  Units Sold  Manufacturing Price  Sale Price  \
# 0   Japan  KENSINGTON      1372.0                  3.0        20.0
# 1   India  KENSINGTON      2762.0                  3.0        20.0
# 2      UK  KENSINGTON      1464.0                  3.0        15.0
# 3   India  KENSINGTON       719.0                  3.0        15.0
# 4  Brazil  KENSINGTON      3576.0                  3.0        15.0
#
#    Gross Sales  Discounts    Sales     COGS   Profit     Date Month Name  \
# 0      27440.0        0.0  27440.0  16185.0  11255.0  43466.0    January
# 1      55240.0        0.0  55240.0  13210.0  42030.0  43466.0    January
# 2      21960.0        0.0  21960.0  21780.0    180.0  43617.0       June
# 3      10785.0        NaN  10785.0   8880.0   1905.0  43617.0       June
# 4      53640.0        0.0  53640.0  24700.0  28940.0  43617.0       June
#
#      Year
# 0  2019.0
# 1  2019.0
# 2  2019.0
# 3  2019.0
# 4  2019.0

# %%
import pandas as pd
excel_df = pd.read_excel("D:\Downlods\Advanced+Pivot+Tables+Exercise+Files\Nashville.xlsx")
excel_df.head()
# Out:
#   Cell In[13], line 2
#     excel_df = pd.read_excel("D:\Downlods\Advanced+Pivot+Tables+Exercise+Files\Nashville.xlsx")
#                                                                                               ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 48-49: malformed \N character escape

# %%
import pandas as pd
excel_df = pd.read_excel("C:\Downloads\ali.xlsx")
excel_df.head()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[24], line 2
#       1 import pandas as pd
# ----> 2 excel_df = pd.read_excel("C:\Downloads\ali.xlsx")
#       3 excel_df.head()
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
import pandas as pd
excel_df = pd.read_excel("D:\Downlods\Advanced+Pivot+Tables+Exercise+Files\Maedeh.xlsx")
shape_of_df = excel_df.shape
excel_df.head(15)
# print("=====================================================================================")
# excel_df.tail(10)
# print("=====================================================================================")
# print(shape_of_df)
# Out:
#     UniqueID           ParcelID            LandUse  \
# 0        2045   007 00 0 125.00      SINGLE FAMILY
# 1       16918   007 00 0 130.00      SINGLE FAMILY
# 2       54582   007 00 0 138.00      SINGLE FAMILY
# 3       43070   007 00 0 143.00      SINGLE FAMILY
# 4       22714   007 00 0 149.00      SINGLE FAMILY
# 5       18367   007 00 0 151.00      SINGLE FAMILY
# 6       19804   007 14 0 002.00      SINGLE FAMILY
# 7       54583   007 14 0 024.00      SINGLE FAMILY
# 8       36500   007 14 0 026.00      SINGLE FAMILY
# 9       19805   007 14 0 034.00      SINGLE FAMILY
# 10      29467  007 14 0A 024.00      SINGLE FAMILY
# 11      10754  007 14 0A 027.00      SINGLE FAMILY
# 12      34751  007 14 0B 010.00  RESIDENTIAL CONDO
# 13       4512   007 15 0 002.00      SINGLE FAMILY
# 14      16919   007 15 0 003.00      SINGLE FAMILY
#
#                           PropertyAddress   SaleDate  SalePrice  \
# 0      1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000
# ...

# %%
import pandas as pd
excel_df = pd.read_excel("D:\Downlods\Advanced+Pivot+Tables+Course+Files\Course Files\Section 3\Sample Sales Data.xlsx")
shape_of_df = excel_df.shape
# excel_df.head(15)
# print("=====================================================================================")
excel_df.tail(10)
# print("=====================================================================================")
# print(shape_of_df)
# Out:
#                       Country    Product  Units Sold  Manufacturing Price  \
# 701  United States of America   Mandarin      1647.0                250.0
# 702                     India   Mandarin       235.0                250.0
# 703                     Japan   Mandarin      3617.0                250.0
# 704                     India   Mandarin      2106.0                250.0
# 705                        UK   Mandarin      2351.0                250.0
# 706                        UK       Luxe      1897.0                260.0
# 707                    Brazil       Luxe       647.0                260.0
# 708                    Brazil  Royal Oak      3621.0                  5.0
# 709                     Japan    Vermont      3221.0                 10.0
# 710  United States of America   Mandarin       493.0                250.0
#
#      Sale Price  Gross Sales  Discounts      Sales      COGS     Profit  \
# 701        20.0      32940.0     801.00   32139.00    2670.0   29469.00
# ...

# %%
import pandas as pd
excel_df = pd.read_excel("D:\Downlods\Advanced+Pivot+Tables+Course+Files\Course Files\Section 3\Sample Sales Data.xlsx")
shape_of_df = excel_df.shape
excel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 711 entries, 0 to 710
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Country              705 non-null    object
#  1   Product              705 non-null    object
#  2   Units Sold           705 non-null    float64
#  3   Manufacturing Price  705 non-null    float64
#  4   Sale Price           705 non-null    float64
#  5   Gross Sales          705 non-null    float64
#  6   Discounts            701 non-null    float64
#  7    Sales               705 non-null    float64
#  8   COGS                 705 non-null    float64
#  9   Profit               705 non-null    float64
#  10  Date                 705 non-null    float64
#  11  Month Name           705 non-null    object
#  12  Year                 705 non-null    float64
# dtypes: float64(10), object(3)
# memory usage: 72.3+ KB

# %%
import pandas as pd
excel_df = pd.read_excel("D:\Downlods\Advanced+Pivot+Tables+Course+Files\Course Files\Section 3\Sample Sales Data.xlsx")
excel_df.describe()
# Out:
#         Units Sold  Manufacturing Price  Sale Price   Gross Sales  \
# count   705.000000           705.000000  705.000000  7.050000e+02
# mean   2380.104965            96.707801  118.154610  2.836409e+05
# std    1199.785920           108.652947  136.802374  3.884636e+05
# min     213.000000             3.000000    7.000000  2.580000e+03
# 25%    1337.000000             5.000000   12.000000  2.418000e+04
# 50%    2370.000000            10.000000   20.000000  5.487000e+04
# 75%    3401.000000           250.000000  300.000000  4.525500e+05
# max    4492.000000           260.000000  350.000000  1.547700e+06
#
#            Discounts         Sales           COGS        Profit          Date  \
# count     701.000000  7.050000e+02     705.000000  7.050000e+02    705.000000
# mean    13131.595207  2.705838e+05  144900.228369  1.256836e+05  43584.093617
# std     22951.895582  3.769561e+05  203424.656086  2.921187e+05    146.850379
# ...

# %%
excel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 711 entries, 0 to 710
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Country              705 non-null    object
#  1   Product              705 non-null    object
#  2   Units Sold           705 non-null    float64
#  3   Manufacturing Price  705 non-null    float64
#  4   Sale Price           705 non-null    float64
#  5   Gross Sales          705 non-null    float64
#  6   Discounts            701 non-null    float64
#  7    Sales               705 non-null    float64
#  8   COGS                 705 non-null    float64
#  9   Profit               705 non-null    float64
#  10  Date                 705 non-null    float64
#  11  Month Name           705 non-null    object
#  12  Year                 705 non-null    float64
# dtypes: float64(10), object(3)
# memory usage: 72.3+ KB

# %%
excel_df[['Profit']].describe()
# Out:
#              Profit
# count  7.050000e+02
# mean   1.256836e+05
# std    2.921187e+05
# min   -7.240720e+05
# 25%    2.308800e+03
# 50%    2.516640e+04
# 75%    9.651100e+04
# max    1.355824e+06

# %%
 print(excel_df.columns)
# Out:
# Index(['Country', 'Product', 'Units Sold', 'Manufacturing Price', 'Sale Price',
#        'Gross Sales', 'Discounts', ' Sales', 'COGS', 'Profit', 'Date',
#        'Month Name', 'Year'],
#       dtype='object')

# %%
excel_df.dtypes
# Out:
# Country                 object
# Product                 object
# Units Sold             float64
# Manufacturing Price    float64
# Sale Price             float64
# Gross Sales            float64
# Discounts              float64
#  Sales                 float64
# COGS                   float64
# Profit                 float64
# Date                   float64
# Month Name              object
# Year                   float64
# dtype: object

# %%
# return two or more columns of data frame
new_df = excel_df[['Country', 'COGS']]
new_df.head()
# Out:
#   Country     COGS
# 0   Japan  16185.0
# 1   India  13210.0
# 2      UK  21780.0
# 3   India   8880.0
# 4  Brazil  24700.0

# %%
# return data frame with special object
partial_df = excel_df[excel_df.Product == 'Vermont']
partial_df.shape
partial_df.head()
# Out:
#    Country  Product  Units_Sold  Manufacturing_Price  Sale_Price  Gross_Sales  \
# 20   Japan  Vermont      2513.0                 10.0        20.0      50260.0
# 21  Brazil  Vermont       883.0                 10.0        15.0      13245.0
# 27  Brazil  Vermont       997.0                 10.0         7.0       6979.0
# 29  Brazil  Vermont      2291.0                 10.0       300.0     687300.0
# 30  Brazil  Vermont      2290.0                 10.0        15.0      34350.0
#
#     Discounts    _Sales      COGS    Profit     Date Month_Name    Year
# 20        0.0   50260.0    2920.0   47340.0  43497.0   February  2019.0
# 21        0.0   13245.0    9740.0    3505.0  43497.0   February  2019.0
# 27        0.0    6979.0    4415.0    2564.0  43678.0     August  2019.0
# 29        0.0  687300.0  197000.0  490300.0  43344.0  September  2018.0
# 30        0.0   34350.0   24720.0    9630.0  43709.0  September  2019.0

# %%
#change the column name(just change in dataframe)
excel_df.columns = [c.replace(' ', '_') for c in excel_df.columns]

# %%
# return data with one condition 
sale_price_under_200 = excel_df[excel_df.Sale_Price < 8][['Country','Sale_Price']]
sale_price_under_200.tail(10)
# Out:
#     Country  Sale_Price
# 633   India         7.0
# 646   Japan         7.0
# 647  Brazil         7.0
# 653      UK         7.0
# 663  Brazil         7.0
# 674      UK         7.0
# 675  Brazil         7.0
# 683  Brazil         7.0
# 708  Brazil         7.0
# 709   Japan         7.0

# %%
# more than one condition
new_condition = excel_df[(excel_df.Sale_Price < 10) & (excel_df.Country == 'Japan')]
new_condition.shape
# Out:
# (20, 13)

# %%
new_condition.head()
# Out:
#     Country     Product  Units_Sold  Manufacturing_Price  Sale_Price  \
# 68    Japan    Mandarin      3785.0                250.0         7.0
# 82    Japan   Royal Oak      1112.0                  5.0         7.0
# 98    Japan  Burlington      2856.0                120.0         7.0
# 191   Japan  Kensington      1137.0                  3.0         7.0
# 196   Japan   Royal Oak      3699.0                  5.0         7.0
#
#      Gross_Sales  Discounts    _Sales     COGS    Profit     Date Month_Name  \
# 68       26495.0      92.82  26402.18   6630.0  19772.18  43525.0      March
# 82        7784.0     128.10   7655.90   9150.0  -1494.10  43678.0     August
# 98       19992.0     146.44  19845.56  10460.0   9385.56  43405.0   November
# 191       7959.0     798.28   7160.72  14255.0  -7094.28  43374.0    October
# 196      25893.0     798.28  25094.72  14255.0  10839.72  43374.0    October
#
#        Year
# 68   2019.0
# 82   2019.0
# 98   2018.0
# 191  2018.0
# 196  2018.0

# %%
new_condition_or = excel_df[(excel_df.Sale_Price < 7) | (excel_df.Discounts > 300)]
new_condition_or.shape
# Out:
# (606, 13)

# %%
new_condition_or.head()
# Out:
#                      Country     Product  Units_Sold  Manufacturing_Price  \
# 65                        UK     Vermont      1823.0                 10.0
# 70                    Brazil  Kensington      1021.0                  3.0
# 73  United States of America  Kensington      2654.0                  3.0
# 74                        UK  Kensington      4174.0                  3.0
# 76                    Brazil  Kensington      1572.0                  3.0
#
#     Sale_Price  Gross_Sales  Discounts     _Sales      COGS     Profit  \
# 65        15.0      27345.0     344.40   27000.60   22960.0    4040.60
# 70       350.0     357350.0    4235.00  353115.00  314600.0   38515.00
# 73       125.0     331750.0     412.50  331337.50   39600.0  291737.50
# 74        12.0      50088.0     320.52   49767.48    8013.0   41754.48
# 76       300.0     471600.0    1482.00  470118.00  123500.0  346618.00
#
#        Date Month_Name    Year
# 65  43497.0   February  2019.0
# ...

# %%
# Data cleaning 
no_of_dups = excel_df.duplicated().sum()
print(no_of_dups)
# Out:
# 10

# %%
no_of_dups_Country = excel_df.duplicated(['Country']).sum()
print(no_of_dups_Country)
# this is used for unique objects such as id
# Out:
# 705

# %%
# drop duplicates
excel_df_without_duplicate = excel_df.drop_duplicates()

# %%
no_of_dups = excel_df_without_duplicate.duplicated().sum()
print(no_of_dups)
# Out:
# 0

# %%
# Dropping the rows which have missing data
df = excel_df_without_duplicate
df_dropna_all = df.dropna(how='all')
print(df, df_dropna_all, titles=["|input : Raw DataFrame|","|Output : df with dropna(how='all')"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[90], line 4
#       2 df = excel_df_without_duplicate
#       3 df_dropna_all = df.dropna(how='all')
# ----> 4 print(df, df_dropna_all, titles=["|input : Raw DataFrame|","|Output : df with dropna(how='all')"])
#
# TypeError: 'titles' is an invalid keyword argument for print()

# %%
# Dropping the rows which have missing data
df = excel_df_without_duplicate
df_dropna_all = df.dropna(how='all')

# %%
df.head(10)
# Out:
#   Country      Product  Units_Sold  Manufacturing_Price  Sale_Price  \
# 0   Japan   KENSINGTON      1372.0                  3.0        20.0
# 1   India   KENSINGTON      2762.0                  3.0        20.0
# 2      UK   KENSINGTON      1464.0                  3.0        15.0
# 3   India   KENSINGTON       719.0                  3.0        15.0
# 4  Brazil   KENSINGTON      3576.0                  3.0        15.0
# 5   India   KENSINGTON      4422.0                  3.0       350.0
# 6     NaN          NaN         NaN                  NaN         NaN
# 7   India  Royal\n Oak      3649.0                  5.0        15.0
# 8   Japan    Royal Oak      4172.0                  5.0        12.0
# 9      UK    Royal Oak      3841.0                  5.0        20.0
#
#    Gross_Sales  Discounts     _Sales      COGS     Profit     Date Month_Name  \
# 0      27440.0        0.0    27440.0   16185.0    11255.0  43466.0    January
# ...

# %%
df_dropna_all.head(10)
# if in the column all of them has an Nan delete it.
# Out:
#    Country      Product  Units_Sold  Manufacturing_Price  Sale_Price  \
# 0    Japan   KENSINGTON      1372.0                  3.0        20.0
# 1    India   KENSINGTON      2762.0                  3.0        20.0
# 2       UK   KENSINGTON      1464.0                  3.0        15.0
# 3    India   KENSINGTON       719.0                  3.0        15.0
# 4   Brazil   KENSINGTON      3576.0                  3.0        15.0
# 5    India   KENSINGTON      4422.0                  3.0       350.0
# 7    India  Royal\n Oak      3649.0                  5.0        15.0
# 8    Japan    Royal Oak      4172.0                  5.0        12.0
# 9       UK    Royal Oak      3841.0                  5.0        20.0
# 10   India  Royal\n Oak      3726.0                  5.0        12.0
#
#     Gross_Sales  Discounts     _Sales      COGS     Profit     Date  \
# 0       27440.0        0.0    27440.0   16185.0    11255.0  43466.0
# 1       55240.0        0.0    55240.0   13210.0    42030.0  43466.0
# ...

# %%
df_dropna_any = df.dropna(how='any')
df_dropna_any.head(10)
# if just one of the column in the row has an NAn data delete it.
# Out:
#    Country      Product  Units_Sold  Manufacturing_Price  Sale_Price  \
# 0    Japan   KENSINGTON      1372.0                  3.0        20.0
# 1    India   KENSINGTON      2762.0                  3.0        20.0
# 2       UK   KENSINGTON      1464.0                  3.0        15.0
# 4   Brazil   KENSINGTON      3576.0                  3.0        15.0
# 5    India   KENSINGTON      4422.0                  3.0       350.0
# 7    India  Royal\n Oak      3649.0                  5.0        15.0
# 8    Japan    Royal Oak      4172.0                  5.0        12.0
# 9       UK    Royal Oak      3841.0                  5.0        20.0
# 10   India  Royal\n Oak      3726.0                  5.0        12.0
# 12  Brazil    Royal Oak      2625.0                  5.0        15.0
#
#     Gross_Sales  Discounts     _Sales      COGS     Profit     Date  \
# 0       27440.0        0.0    27440.0   16185.0    11255.0  43466.0
# 1       55240.0        0.0    55240.0   13210.0    42030.0  43466.0
# ...

# %%
df_dropna_subset = df.dropna(subset=['Country', 'Discounts'])
df_dropna_subset.head(10)
# delete the rows that in their selected columns have missed data
# Out:
#    Country      Product  Units_Sold  Manufacturing_Price  Sale_Price  \
# 0    Japan   KENSINGTON      1372.0                  3.0        20.0
# 1    India   KENSINGTON      2762.0                  3.0        20.0
# 2       UK   KENSINGTON      1464.0                  3.0        15.0
# 4   Brazil   KENSINGTON      3576.0                  3.0        15.0
# 5    India   KENSINGTON      4422.0                  3.0       350.0
# 7    India  Royal\n Oak      3649.0                  5.0        15.0
# 8    Japan    Royal Oak      4172.0                  5.0        12.0
# 9       UK    Royal Oak      3841.0                  5.0        20.0
# 10   India  Royal\n Oak      3726.0                  5.0        12.0
# 12  Brazil    Royal Oak      2625.0                  5.0        15.0
#
#     Gross_Sales  Discounts     _Sales      COGS     Profit     Date  \
# 0       27440.0        0.0    27440.0   16185.0    11255.0  43466.0
# 1       55240.0        0.0    55240.0   13210.0    42030.0  43466.0
# ...
